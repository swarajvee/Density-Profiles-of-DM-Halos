# %%
import numpy as np 
import matplotlib.pyplot as plt 
from hmf.halos import mass_definitions
from hmf.mass_function import FittingFunction
import astropy

# %%
import asdf
af = asdf.open("/Users/swarajv/Education/s10 MSc Major Project/Hubble data/z8.000/halo_info/halo_info_000.asdf",copy_arrays=True)
af.info(max_rows=None, max_cols=None)
# Out:
# root (AsdfObject)
# ├─asdf_library (Software)
# │ ├─author (str): Space Telescope Science Institute
# │ ├─homepage (str): http://github.com/spacetelescope/asdf
# │ ├─name (str): asdf
# │ └─version (str): 2.6.0.dev11+g03788bc
# ├─history (dict)
# │ └─extensions (list)
# │   └─[0] (ExtensionMetadata)
# │     ├─extension_class (str): asdf.extension.BuiltinExtension
# │     └─software (Software)
# │       ├─name (str): asdf
# │       └─version (str): 2.6.0.dev11+g03788bc
# ├─data (dict)
# │ ├─L0_N (NDArrayType): shape=(22080,), dtype=uint32
# │ ├─L2_N (NDArrayType): shape=(22080, 5), dtype=uint32
# │ ├─N (NDArrayType): shape=(22080,), dtype=uint32
# │ ├─SO_L2max_central_density (NDArrayType): shape=(22080,), dtype=float32
# │ ├─SO_L2max_central_particle (NDArrayType): shape=(22080, 3), dtype=float32
# │ ├─SO_L2max_radius (NDArrayType): shape=(22080,), dtype=float32
# │ ├─SO_central_density (NDArrayType): shape=(22080,), dtype=float32
# ...

# %%
print(FittingFunction.get_models())
# Out:
# {'PS': <class 'hmf.mass_function.fitting_functions.PS'>, 'SMT': <class 'hmf.mass_function.fitting_functions.SMT'>, 'ST': <class 'hmf.mass_function.fitting_functions.ST'>, 'Jenkins': <class 'hmf.mass_function.fitting_functions.Jenkins'>, 'Warren': <class 'hmf.mass_function.fitting_functions.Warren'>, 'Reed03': <class 'hmf.mass_function.fitting_functions.Reed03'>, 'Reed07': <class 'hmf.mass_function.fitting_functions.Reed07'>, 'Peacock': <class 'hmf.mass_function.fitting_functions.Peacock'>, 'Angulo': <class 'hmf.mass_function.fitting_functions.Angulo'>, 'AnguloBound': <class 'hmf.mass_function.fitting_functions.AnguloBound'>, 'Watson_FoF': <class 'hmf.mass_function.fitting_functions.Watson_FoF'>, 'Watson': <class 'hmf.mass_function.fitting_functions.Watson'>, 'Crocce': <class 'hmf.mass_function.fitting_functions.Crocce'>, 'Courtin': <class 'hmf.mass_function.fitting_functions.Courtin'>, 'Bhattacharya': <class 'hmf.mass_function.fitting_functions.Bhattacharya'>, 'Tinker08': <class 'hmf
# ...

# %%
help(FittingFunction)
# Out:
# Help on class FittingFunction in module hmf.mass_function.fitting_functions:
#
# class FittingFunction(hmf._internals._framework.Component)
#  |  FittingFunction(nu2: numpy.ndarray, m: Optional[numpy.ndarray] = None, z: float = 0.0, n_eff: Optional[numpy.ndarray] = None, mass_definition: Optional[hmf.halos.mass_definitions.MassDefinition] = None, cosmo: astropy.cosmology.flrw.base.FLRW = FlatLambdaCDM(name='Planck15', H0=<Quantity 67.74 km / (Mpc s)>, Om0=0.3075, Tcmb0=<Quantity 2.7255 K>, Neff=3.046, m_nu=<Quantity [0.  , 0.  , 0.06] eV>, Ob0=0.0486), delta_c: float = 1.686, **model_parameters)
#  |
#  |  Base-class for a halo mass function fit.
#  |
#  |  This class should not be called directly, rather use a subclass which is
#  |  specific to a certain fitting formula. The only method necessary to define
#  |  for any subclass is `fsigma`, as well as a dictionary of default parameters
#  |  as a class variable `_defaults`. Model parameters defined here are accessed
# ...

# %%
mf= FittingFunction(nu2= 0.9649, z= 8.072500247186802, n_eff= 3.04, cosmo: astropy.cosmology.flrw.base.FLRW = FlatLamdaCDM(name='Planck18', H0= 67.36,Om0= 0.315192, Tcmb0= 2.7255, Neff= 3.046))
# Out:
#   Cell In[20], line 1
#     mf= FittingFunction(nu2= 0.9649, z= 8.072500247186802, n_eff= 3.04, cosmo: astropy.cosmology.flrw.base.FLRW = FlatLamdaCDM(name='Planck18', H0= 67.36,Om0= 0.315192, Tcmb0= 2.7255, Neff= 3.046))
#                                                                              ^
# SyntaxError: positional argument follows keyword argument
